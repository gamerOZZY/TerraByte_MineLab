# %%
import psycopg2 as psy

conexion = psy.connect(
    database = "bd",
    user = "gamerOZZY",
    password = "123",
    host = "localhost",
    port = 5432
)

conn = conexion.cursor()

conn.execute("SELECT version();")
